# %% [markdown]
# <a href="https://colab.research.google.com/github/ForestroAung/PythonProject/blob/master/Expression%26Arithmetic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
first_integer=20
sec_integer=30
add_result=first_integer+sec_integer
print('Sum of two numbers',add_result)
# Out:
# Sum of two numbers 50

# %%
sub_result= first_integer- sec_integer
print('Abstraction is',sub_result)
# Out:
# Abstraction is -10

# %%
multi_result=first_integer*sec_integer
print('Multiplication is',multi_result)
# Out:
# Multiplication is 600

# %%
true_div= first_integer/sec_integer
print('True Division is',true_div)
print(type(true_div))
# Out:
# True Division is 0.6666666666666666
# <class 'float'>

# %%
floor_div=first_integer//sec_integer
print('Floor Division is',floor_div)
print(type(floor_div))
# Out:
# Floor Division is 0
# <class 'int'>

# %%
print(22/7)
# Out:
# 3.142857142857143

# %%
num=22
num1=7
floor_division=num//num1
print(floor_division)
# Out:
# 3

# %%
num3=(int(input("Write first number")))
num4=(int(input('Type second number')))
result=num3-num4
print('Calculation is',result)
print(type(result))
# Out:
# Write first number4
# Type second number6
# Calculation is -2
# <class 'int'>

# %%
first=(('Hi'))
sec=(input('Your Name'))
print(first+sec)
# Out:
# Your NameBee
# HiBee

# %%
Fruit="Mango\n"*5
print(Fruit)
# Out:
# Mango
# Mango
# Mango
# Mango
# Mango

# %%
print('Five times: {}'.format(5* 'Fruit\t'))
# Out:
# Five times: Fruit	Fruit	Fruit	Fruit	Fruit

# %%
hat_height=24
person_height=190
total_height_meters=(hat_height+person_height)/100
print(total_height_meters)
# Out:
# 2.14

# %%
a='Yes'*5
b='No'*4
print(a)
print(b)
print(a+b)
# Out:
# YesYesYesYesYes
# NoNoNoNo
# YesYesYesYesYesNoNoNoNo

# %%
no1=int(input('Enter your first number:'))
no2=int(input('Enter your second number:'))
Q=int(no1/no2)
r=(no1%no2)
print('Quioent is:',Q)
print('Remainder is:',r)
print(f'The quotient of {no1} and {no2} is {Q} with a remainder{r}')
# Out:
# Enter your first number:4
# Enter your second number:3
# Quioent is: 1
# Remainder is: 1
# The quotient of 4 and 3 is 1 with a remainder1

# %%
print('Please enter two numbers to divide')
dividend=int(input('Please enter the dividend'))
divisor=int(input('Please enter the divisor'))
print(dividend,'\n', divisor,'=',dividend/divisor)
# Out:
# Please enter two numbers to divide
# Please enter the dividend10

# %%
print('Please enter two numbers to divide')
dividend=int(input('Please enter the dividend'))
divisor=int(input('Please enter the divisor'))
print(dividend,'\n', divisor,'=',divisor/dividend)

# %%
num=eval(input('Please enter your number:'))
print(type(num))

# %%
degreeF=float(input("Please enter your F"))
degreeC= 5/9*(degreeF-32)
print(f"degree F=> {degreeF}\N{DEGREE SIGN}")
print(f"degree F=> {degreeF}\N{DEGREE SIGN}F=> degree C{degreeC}")
# Out:
# Please enter your F35
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-fb14879f4eff> in <cell line: 3>()
#       1 degreeF=float(input("Please enter your F"))
#       2 degreeC= 5/9*(degreeF-32)
# ----> 3 print(f"degree F=> {degreeF}\N{DEGREE SIGN}")
#       4 print(f"degree F=> {degreeF}\N{DEGREE SIGN}F=> degree C{degreeC}")
#
# TypeError: 'str' object is not callable

# %%
city=('Yangon','Mandalay','Myitkyina',(1,2))
city=list(city)
city[2]='Mogok'
#print(city)
print(tuple(city))
# Out:
# ('Yangon', 'Mandalay', 'Mogok', (1, 2))

# %%
outFile=open('sample.txt','w')
outFile.write('My first output file')
outFile.close()

# %%
outFile=open('sample.txt','w')
outFile.write('My second output file!\n')
outFile.write('Write some more')
outFile.close()

# %%
outFile=open('sample.txt','a')
outFile.write('\nOK')
outFile.close()

# %%
writeFile=open('me.txt','w')
lines_of_text=['Red\n','Green','\nBlue']
writeFile.writelines(lines_of_text)
writeFile.close()

# %%
import os

# %%
os.rename('me.txt','sample4.txt')

# %%
os.remove('sample4.txt')

# %%
os.mkdir('hello')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-27-bf8cb31503d1> in <cell line: 1>()
# ----> 1 os.mkdir('hello')
#
# FileExistsError: [Errno 17] File exists: 'hello'

# %%
os.getcwd()
# Out:
# '/content'

# %%
cd'/content/sample_data'
# Out:
# /content/sample_data

# %%
os.getcwd()
# Out:
# '/content/sample_data'

# %%
ls
# Out:
# anscombe.json*                mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md*

# %%
cd ..
# Out:
# /content

# %%
os.getcwd()
# Out:
# '/content'

# %%
os.rmdir('/content/hello')

# %%
import pandas as pd
data= pd.read_csv('/content/sample_data/california_housing_test.csv')

# %%
data
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
a=[1,2,3]
b=[4,5,6]
c=a+b
print(c)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
for i,j in zip(a,b):
  print(i+j)
# Out:
# 5
# 7
# 9

# %%
t=['a','b','c']
t.append('d')

# %%
t1=['Htet','Myat']
t2=['Noe','Aung']
t2.extend(t1)
print(t2)
# Out:
# ['Noe', 'Aung', 'Htet', 'Myat']

# %%
t=['a','b','c']
x=t.pop(1)
print(t)
print(x)
# Out:
# ['a', 'c']
# b

# %%
x
# Out:
# 'b'
